# %%
a = 100

# %%
## Declaring  and Assigning Variables in Python

age = 25
height= 6.1
name="Souvik"
is_student=True

## printing the Variables 


print("age:" , age)
print("height:", height)
print("name:", name)
print("is_student:", is_student)
# Out:
# age: 25
# height: 6.1
# name: Souvik
# is_student: True

# %%
## Naming  Conversation
## Variable names Should be Descripted
## They must start with a letter or an '_' and contains and underscores
## Variables  name case sensitive

#valid variable names

first_name = "Alice"

# %%
# Invalid Variable Names 
#2age=30
#first-name = "Alice"
##@name="Alice"
# Out:
#   Cell In[6], line 4
#     @name="Alice"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
## Case Sensitivity
name =  "Alice"
Name= "Animous"

# %%
## Understanding Variable types
## Python is Dynamically typed, a Variable is determined at runtime

age = 28
height= 6.1
name="ALice"
is_student = True

print(type(name))
# Out:
# <class 'str'>

# %%
age = 30
print(type(age))
## Type checking and conversion
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 30
# <class 'str'>

# %%
height=6.1
print(type(height))
# Out:
# <class 'float'>

# %%
int(height)
# Out:
# 6

# %%
float(int(height))
# Out:
# 6.0

# %%
## Dynamic Typing

var = 10
print(var,type(var))

var = "Hello"
print(var, type(var))

var = 3.14
print(var, type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
## Input
age=int(input("What is the age "))
print(age, type(age))
# Out:
# 21 <class 'int'>

# %%
## Simple calculator 

num1 = float(input("Enter the number :"))
num2 = float(input("Enter the second number :"))

sum = num1 + num2
difference = num1 - num2
product = num1 * num2
quotent = num1 / num2

print("sum:", sum)
print("difference:", difference)
print("product:", product)
print("quotent:", quotent)
# Out:
# sum: 156.0
# difference: 12.0
# product: 6048.0
# quotent: 1.1666666666666667
