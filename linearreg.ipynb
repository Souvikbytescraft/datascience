# %% [markdown]
# 1+1

# %%
1+1

# %%
12 + 16
# Out:
# 28

# %%
380 + 570
# Out:
# 950

# %%
168 + 472
# Out:
# 640

# %%
30 + 30

# %%
## Basic syntax Rules in Python
## Case Sensitivity - python in case sensitive

name="krishna"
Name="Bramha"

print(name)
print(Name)
# Out:
# krishna
# Bramha

# %%
## Indentation
## python uses indentation to define blocks of code. consistent use of spaces (comonly) or a tab is required.

age = 32
if age >= 30:
    print(age)

    print(age)
# Out:
# 32
# 32

# %%
## this is single line comment
print("hello world")
# Out:
# hello world

# %%
## Line continuation
Total = 1+2+3+4+5+6+7+8+9+\
4+5+6
print(Total)
# Out:
# 60

# %%
## Multiple line statesment on a single line 
x = 5; y = 10; z = 15
print(x + y + z)
# Out:
# 30

# %%
## Multiple line statesment on a single line 
x = 5; y = 10; z = x + y
print(z)
# Out:
# 15

# %%
## understand sementics In Python
age = 32 ##age is  an integer
name = "krishna" ## name is a string

# %%
## type Inference
type(age)
# Out:
# int

# %%
## type l
type(name)
# Out:
# str

# %%
## type Inference

variable = 20
print(type(variable))
variable = "Krishna"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age = 32
if age>=30:
 print(age)
# Out:
# 32

# %%
## Name error
 a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
## code examples of indentation
if True:
   print("correct Indentation")
   if False:
       print("Tis ont print")
       
   print("this will print")
print("Outside the if Block")
# Out:
# correct Indentation
# this will print
# Outside the if Block
